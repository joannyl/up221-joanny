# %% [markdown]
# # Age in Los Angeles
# The graphics below are based on data regarding age in Los Angeles.
#
# By: Joanny Leyva

# %% [markdown]
# ### Step 1: Import Data

# %%
import pandas as pd

# %%
df = pd.read_csv('Data/Age_Census.csv')

# %% [markdown]
# ### Data Scan

# %% [markdown]
# The data has 2498 rows and 68 columns

# %%
df.shape
# Out:
# (2498, 68)

# %% [markdown]
# First five rows of the column and first/last 10 colums of the data

# %%
df.head()
# Out:
#      Geo_FIPS                                          Geo_QName Geo_FILEID  \
# 0  6037101110  Census Tract 1011.10, Los Angeles County, Cali...      ACSSF
# 1  6037101122  Census Tract 1011.22, Los Angeles County, Cali...      ACSSF
# 2  6037101220  Census Tract 1012.20, Los Angeles County, Cali...      ACSSF
# 3  6037101221  Census Tract 1012.21, Los Angeles County, Cali...      ACSSF
# 4  6037101222  Census Tract 1012.22, Los Angeles County, Cali...      ACSSF
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO  Geo_US  Geo_REGION  \
# 0         ca         140            0          4200     NaN         NaN
# 1         ca         140            0          4201     NaN         NaN
# 2         ca         140            0          4202     NaN         NaN
# 3         ca         140            0          4203     NaN         NaN
# 4         ca         140            0          4204     NaN         NaN
#
#    Geo_DIVISION  ...  SE_A01001_004  SE_A01001_005  SE_A01001_006  \
# ...

# %% [markdown]
# Overriding defaluts to view the entire table.

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# Can now view all 68 columns in random row

# %%
df.sample()
# Out:
#         Geo_FIPS                                          Geo_QName  \
# 2040  6037576901  Census Tract 5769.01, Los Angeles County, Cali...
#
#      Geo_FILEID Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO  Geo_US  \
# 2040      ACSSF         ca         140            0          6240     NaN
#
#       Geo_REGION  Geo_DIVISION  Geo_STATECE  Geo_STATE  Geo_COUNTY  \
# 2040         NaN           NaN          NaN          6          37
#
#       Geo_COUSUB  Geo_PLACE  Geo_TRACT  Geo_BLKGRP  Geo_CONCIT  Geo_AIANHH  \
# 2040         NaN        NaN     576901         NaN         NaN         NaN
#
#       Geo_AIANHHFP  Geo_AIHHTLI  Geo_AITSCE  Geo_AITS  Geo_ANRC  Geo_CBSA  \
# 2040           NaN          NaN         NaN       NaN       NaN       NaN
#
#       Geo_CSA  Geo_METDIV  Geo_MACC  Geo_MEMI  Geo_NECTA  Geo_CNECTA  \
# 2040      NaN         NaN       NaN       NaN        NaN         NaN
#
#       Geo_NECTADIV  Geo_UA  Geo_UACP  Geo_CDCURR  Geo_SLDU  Geo_SLDL  Geo_VTD  \
# ...

# %% [markdown]
# Data types:

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2498 entries, 0 to 2497
# Data columns (total 68 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geo_FIPS       2498 non-null   int64
#  1   Geo_QName      2498 non-null   object
#  2   Geo_FILEID     2498 non-null   object
#  3   Geo_STUSAB     2498 non-null   object
#  4   Geo_SUMLEV     2498 non-null   int64
#  5   Geo_GEOCOMP    2498 non-null   int64
#  6   Geo_LOGRECNO   2498 non-null   int64
#  7   Geo_US         0 non-null      float64
#  8   Geo_REGION     0 non-null      float64
#  9   Geo_DIVISION   0 non-null      float64
#  10  Geo_STATECE    0 non-null      float64
#  11  Geo_STATE      2498 non-null   int64
#  12  Geo_COUNTY     2498 non-null   int64
#  13  Geo_COUSUB     0 non-null      float64
#  14  Geo_PLACE      0 non-null      float64
#  15  Geo_TRACT      2498 non-null   int64
#  16  Geo_BLKGRP     0 non-null      float64
# ...

# %% [markdown]
# ### Reimporting data

# %% [markdown]
# Reimporting data to make sure leading numbers, that python originially cropped, are included.

# %% [markdown]
# Specifying the FIPS column as a string

# %%
df = pd.read_csv(
    'Data/Age_Census.csv',
    dtype=
    {
        'Geo_FIPS':str,
        'Geo_STATE':str,
        'Geo_COUNTY': str
    }
)

# %% [markdown]
# Viewing the first 5 rows of data again

# %%
df.head()
# Out:
#       Geo_FIPS                                          Geo_QName Geo_FILEID  \
# 0  06037101110  Census Tract 1011.10, Los Angeles County, Cali...      ACSSF
# 1  06037101122  Census Tract 1011.22, Los Angeles County, Cali...      ACSSF
# 2  06037101220  Census Tract 1012.20, Los Angeles County, Cali...      ACSSF
# 3  06037101221  Census Tract 1012.21, Los Angeles County, Cali...      ACSSF
# 4  06037101222  Census Tract 1012.22, Los Angeles County, Cali...      ACSSF
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO  Geo_US  Geo_REGION  \
# 0         ca         140            0          4200     NaN         NaN
# 1         ca         140            0          4201     NaN         NaN
# 2         ca         140            0          4202     NaN         NaN
# 3         ca         140            0          4203     NaN         NaN
# 4         ca         140            0          4204     NaN         NaN
#
# ...

# %% [markdown]
# Confirming new datafram has the correct datatypes

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2498 entries, 0 to 2497
# Data columns (total 68 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geo_FIPS       2498 non-null   object
#  1   Geo_QName      2498 non-null   object
#  2   Geo_FILEID     2498 non-null   object
#  3   Geo_STUSAB     2498 non-null   object
#  4   Geo_SUMLEV     2498 non-null   int64
#  5   Geo_GEOCOMP    2498 non-null   int64
#  6   Geo_LOGRECNO   2498 non-null   int64
#  7   Geo_US         0 non-null      float64
#  8   Geo_REGION     0 non-null      float64
#  9   Geo_DIVISION   0 non-null      float64
#  10  Geo_STATECE    0 non-null      float64
#  11  Geo_STATE      2498 non-null   object
#  12  Geo_COUNTY     2498 non-null   object
#  13  Geo_COUSUB     0 non-null      float64
#  14  Geo_PLACE      0 non-null      float64
#  15  Geo_TRACT      2498 non-null   int64
#  16  Geo_BLKGRP     0 non-null      float64
# ...

# %% [markdown]
# ### Dropping and Deleting Null Columns

# %% [markdown]
# Using the isna() command to view null columns, .all() for all empty values, and .any() for all columns with one or more empty values

# %%
df.columns[df.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_STATECE',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_BLKGRP',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITSCE',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_CNECTA',
#  'Geo_NECTADIV',
#  'Geo_UA',
#  'Geo_UACP',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_VTD',
#  'Geo_ZCTA3',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_TAZ',
#  'Geo_UGA',
#  'Geo_PUMA5',
#  'Geo_PUMA1',
#  'Geo_BTTR',
#  'Geo_BTBG',
#  'Geo_PLACESE']

# %% [markdown]
# Eliminating null columns and reviewing new data

# %%
df = df.dropna(axis=1,how="all")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2498 entries, 0 to 2497
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geo_FIPS       2498 non-null   object
#  1   Geo_QName      2498 non-null   object
#  2   Geo_FILEID     2498 non-null   object
#  3   Geo_STUSAB     2498 non-null   object
#  4   Geo_SUMLEV     2498 non-null   int64
#  5   Geo_GEOCOMP    2498 non-null   int64
#  6   Geo_LOGRECNO   2498 non-null   int64
#  7   Geo_STATE      2498 non-null   object
#  8   Geo_COUNTY     2498 non-null   object
#  9   Geo_TRACT      2498 non-null   int64
#  10  Geo_GEOID      2498 non-null   object
#  11  Geo_NAME       2498 non-null   object
#  12  SE_A01001_001  2498 non-null   int64
#  13  SE_A01001_002  2498 non-null   int64
#  14  SE_A01001_003  2498 non-null   int64
#  15  SE_A01001_004  2498 non-null   int64
#  16  SE_A01001_005  2498 non-null   int64
# ...

# %%
df.head()
# Out:
#       Geo_FIPS                                          Geo_QName Geo_FILEID  \
# 0  06037101110  Census Tract 1011.10, Los Angeles County, Cali...      ACSSF
# 1  06037101122  Census Tract 1011.22, Los Angeles County, Cali...      ACSSF
# 2  06037101220  Census Tract 1012.20, Los Angeles County, Cali...      ACSSF
# 3  06037101221  Census Tract 1012.21, Los Angeles County, Cali...      ACSSF
# 4  06037101222  Census Tract 1012.22, Los Angeles County, Cali...      ACSSF
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO Geo_STATE Geo_COUNTY  \
# 0         ca         140            0          4200        06        037
# 1         ca         140            0          4201        06        037
# 2         ca         140            0          4202        06        037
# 3         ca         140            0          4203        06        037
# 4         ca         140            0          4204        06        037
#
# ...

# %% [markdown]
# ### Defining columns to keep
#
# Using the data dictionary (saved in Jupyter files if interested), I selected the identifiers for the columns I wanted to keep for my data:
#
# A01001_001:     Total Population:
#
# A01001_002:     Total Population: Under 5 Years
#
# A01001_003:     Total Population: 5 to 9 Years
#
# A01001_004:     Total Population: 10 to 14 Years
#
# A01001_005:     Total Population: 15 to 17 Years
#
# A01001_006:     Total Population: 18 to 24 Years
#
# A01001_007:     Total Population: 25 to 34 Years
#
# A01001_008:     Total Population: 35 to 44 Years
#
# A01001_009:     Total Population: 45 to 54 Years
#
# A01001_010:     Total Population: 55 to 64 Years
#
# A01001_011:     Total Population: 65 to 74 Years
#
# A01001_012:     Total Population: 75 to 84 Years
#
# A01001_013:     Total Population: 85 Years and Over

# %% [markdown]
# Creating subset of my dataframe:

# %%
columns_to_keep = ['Geo_FIPS',
                   'SE_A01001_001',
                   'SE_A01001_002',
                   'SE_A01001_003',
                   'SE_A01001_004',
                   'SE_A01001_005',
                   'SE_A01001_006',
                   'SE_A01001_007',
                   'SE_A01001_008',
                   'SE_A01001_009',
                   'SE_A01001_010',
                    'SE_A01001_011',
                  'SE_A01001_012',
                  'SE_A01001_013']

df2 = df[columns_to_keep]

# %% [markdown]
# Double checking it worked :)

# %%
df2.head()
# Out:
#       Geo_FIPS  SE_A01001_001  SE_A01001_002  SE_A01001_003  SE_A01001_004  \
# 0  06037101110           3879            131             96            178
# 1  06037101122           4247            131            217            247
# 2  06037101220           3583            132            196            245
# 3  06037101221           3723            134            146            207
# 4  06037101222           2690             56            276            166
#
#    SE_A01001_005  SE_A01001_006  SE_A01001_007  SE_A01001_008  SE_A01001_009  \
# 0            172            235            557            554            586
# 1             91            415            313            421            776
# 2             72            294            512            437            621
# 3            158            448            425            659            407
# 4             19            184            404            397            495
#
# ...

# %% [markdown]
# ### Renaming columns
#
# Renaming columns to correspond with population groups

# %%
columns = list(df2) 
columns
# Out:
# ['Geo_FIPS',
#  'SE_A01001_001',
#  'SE_A01001_002',
#  'SE_A01001_003',
#  'SE_A01001_004',
#  'SE_A01001_005',
#  'SE_A01001_006',
#  'SE_A01001_007',
#  'SE_A01001_008',
#  'SE_A01001_009',
#  'SE_A01001_010',
#  'SE_A01001_011',
#  'SE_A01001_012',
#  'SE_A01001_013']

# %%
df2.columns = ['FIPS',
'Total Population',
'TotalPop <5',
'TotalPop 5 to 9',
'TotalPop 10 to 14',
'TotalPop 15 to 17',
'TotalPop 18 to 24',
'TotalPop 25 to 34',
'TotalPop 35 to 44',
'TotalPop 45 to 54',
'TotalPop 55 to 64',
'TotalPop 65 to 74',
'TotalPop 75 to 84',
'85 and older']

# %% [markdown]
# Double checking it worked :)

# %%
df2.sample(5)
# Out:
#              FIPS  Total Population  TotalPop <5  TotalPop 5 to 9  \
# 979   06037269905              2126           78               37
# 1362  06037408623              3189          125              115
# 348   06037139303              4477          119              296
# 351   06037139502              2874          211              213
# 1864  06037551700              6357          284              386
#
#       TotalPop 10 to 14  TotalPop 15 to 17  TotalPop 18 to 24  \
# 979                  15                 28                173
# 1362                214                129                277
# 348                 150                162                290
# 351                 100                 35                265
# 1864                516                295                454
#
#       TotalPop 25 to 34  TotalPop 35 to 44  TotalPop 45 to 54  \
# 979                 975                423                124
# 1362                372                282                472
# ...

# %% [markdown]
# ### Stats

# %% [markdown]
# Statistics of the total population under 5 years of age of the first 5 census tracts in the dataframe

# %%
df2['TotalPop <5'].head()
# Out:
# 0    131
# 1    131
# 2    132
# 3    134
# 4     56
# Name: TotalPop <5, dtype: int64

# %% [markdown]
# Mean of the population under 5 years of age

# %%
df2['TotalPop <5'].mean()
# Out:
# 228.3294635708567

# %% [markdown]
# General stats of the total population under 5.
#
# There are some tracts with zero children under 5 and a max of 1334

# %%
df2['TotalPop <5'].describe()
# Out:
# count    2498.000000
# mean      228.329464
# std       142.531621
# min         0.000000
# 25%       127.250000
# 50%       207.000000
# 75%       305.000000
# max      1334.000000
# Name: TotalPop <5, dtype: float64

# %% [markdown]
# Histogram demonstrates a positive distribution

# %%
df2['TotalPop <5'].plot.hist(bins=50)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# Box plot

# %%
df2.boxplot(column=['TotalPop <5'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Sorting
#
# Sorting and plotting census tracts with highest populations of children under 5 years old

# %%
df_sorted = df2.sort_values(by='TotalPop <5',ascending = False)

# %%
df_sorted[['FIPS','TotalPop <5']].head(10)
# Out:
#              FIPS  TotalPop <5
# 1028  06037275604         1334
# 2441  06037920312          913
# 2421  06037920047          898
# 2411  06037920035          877
# 2417  06037920043          872
# 1804  06037542502          872
# 2438  06037920121          828
# 1740  06037535101          820
# 2360  06037910216          782
# 2406  06037920028          774

# %%
df_sorted.head(10).plot.bar(x='FIPS',
                            y='TotalPop <5')
# Out:
# <AxesSubplot: xlabel='FIPS'>

# %% [markdown]
# Making the graph above look nicer!

# %%
df_sorted.head(10).plot.barh(x='FIPS',
                            y='TotalPop <5', 
                            title='Top 10 Census Tracts with Highest Population in Los Angeles County in 2020',
                            color='teal')
# Out:
# <AxesSubplot: title={'center': 'Top 10 Census Tracts with Highest Population in Los Angeles County in 2020'}, ylabel='FIPS'>

# %% [markdown]
# ### Filtering and Subsetting Data

# %% [markdown]
# Filtering for tracts that don't have any children under 5.

# %%
df2[df2['TotalPop <5']==0]
# Out:
#              FIPS  Total Population  TotalPop <5  TotalPop 5 to 9  \
# 117   06037115103              3037            0                0
# 225   06037125321              2718            0               39
# 226   06037125322              1979            0                0
# 229   06037125404              2696            0                0
# 384   06037143605              1724            0               14
# 456   06037190101              1659            0               54
# 586   06037206201              2134            0                0
# 588   06037206301              1819            0               12
# 590   06037206303              2430            0               25
# 594   06037207303              2242            0               13
# 596   06037207305               717            0                0
# 597   06037207306              1978            0                0
# 598   06037207307              1461            0                0
# ...

# %% [markdown]
# Creating a new variable for the filter above

# %%
df_no_pop = df2[df2['TotalPop <5']==0]

# %% [markdown]
# How many census tracts with no children under 5 years old?

# %%
print('There are ' + str(len(df_no_pop)) + ' census tracts with no children under 5 in them')
# Out:
# There are 60 census tracts with no children under 5 in them

# %%
df_no_pop[['FIPS','TotalPop <5']]
# Out:
#              FIPS  TotalPop <5
# 117   06037115103            0
# 225   06037125321            0
# 226   06037125322            0
# 229   06037125404            0
# 384   06037143605            0
# 456   06037190101            0
# 586   06037206201            0
# 588   06037206301            0
# 590   06037206303            0
# 594   06037207303            0
# 596   06037207305            0
# 597   06037207306            0
# 598   06037207307            0
# 599   06037207308            0
# 603   06037207711            0
# 605   06037207901            0
# 642   06037211123            0
# 697   06037214903            0
# 698   06037214904            0
# 761   06037222700            0
# 771   06037224702            0
# 938   06037265301            0
# 941   06037265306            0
# 1039  06037276608            0
# 1221  06037402404            0
# 2049  06037577504            0
# 2058  06037578100            0
# 2060  06037599100            0
# 2334  06037901003            0
# ...

# %% [markdown]
# ### Maps :)

# %% [markdown]
# Using data from LA County's GIS portal in geojson format to map

# %%
import geopandas as gpd

# %%
tracts=gpd.read_file('Data/Census_Tracts_2020.geojson')
tracts.head()
# Out:
#    OBJECTID    CT20    LABEL   ShapeSTArea  ShapeSTLength  \
# 0         1  101110  1011.10  1.229562e+07   15083.854287
# 1         2  101122  1011.22  2.845774e+07   31671.455844
# 2         3  101220  1012.20  7.522093e+06   12698.783810
# 3         4  101221  1012.21  3.812000e+06    9161.710543
# 4         5  101222  1012.22  3.191371e+06    9980.600461
#
#                                             geometry
# 0  POLYGON ((-118.28491 34.25948, -118.28492 34.2...
# 1  POLYGON ((-118.29015 34.27417, -118.29015 34.2...
# 2  POLYGON ((-118.28100 34.25592, -118.28198 34.2...
# 3  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  POLYGON ((-118.28594 34.25405, -118.28594 34.2...

# %% [markdown]
# Testing out the map

# %%
tracts.plot(figsize=(12,10))
# Out:
# <AxesSubplot: >

# %%
tracts.info(verbose=True, show_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2495 entries, 0 to 2494
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OBJECTID       2495 non-null   int64
#  1   CT20           2495 non-null   object
#  2   LABEL          2495 non-null   object
#  3   ShapeSTArea    2495 non-null   float64
#  4   ShapeSTLength  2495 non-null   float64
#  5   geometry       2495 non-null   geometry
# dtypes: float64(2), geometry(1), int64(1), object(2)
# memory usage: 117.1+ KB

# %%
tracts = tracts[['CT20','geometry']]
tracts.head()
# Out:
#      CT20                                           geometry
# 0  101110  POLYGON ((-118.28491 34.25948, -118.28492 34.2...
# 1  101122  POLYGON ((-118.29015 34.27417, -118.29015 34.2...
# 2  101220  POLYGON ((-118.28100 34.25592, -118.28198 34.2...
# 3  101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  101222  POLYGON ((-118.28594 34.25405, -118.28594 34.2...

# %%
# create a FIPS column
tracts['FIPS'] ='06' + '037' + tracts['CT20']

# %% [markdown]
# Merging data to map census data from social explorer

# %% [markdown]
# + Creating a new dataframe

# %%
tracts_age=tracts.merge(df2,on="FIPS")

# %%
tracts_age.head()
# Out:
#      CT20                                           geometry         FIPS  \
# 0  101110  POLYGON ((-118.28491 34.25948, -118.28492 34.2...  06037101110
# 1  101122  POLYGON ((-118.29015 34.27417, -118.29015 34.2...  06037101122
# 2  101220  POLYGON ((-118.28100 34.25592, -118.28198 34.2...  06037101220
# 3  101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...  06037101221
# 4  101222  POLYGON ((-118.28594 34.25405, -118.28594 34.2...  06037101222
#
#    Total Population  TotalPop <5  TotalPop 5 to 9  TotalPop 10 to 14  \
# 0              3879          131               96                178
# 1              4247          131              217                247
# 2              3583          132              196                245
# 3              3723          134              146                207
# 4              2690           56              276                166
#
#    TotalPop 15 to 17  TotalPop 18 to 24  TotalPop 25 to 34  TotalPop 35 to 44  \
# ...

# %% [markdown]
# Now to make some maps :)

# %%
tracts_age.plot(figsize=(12,10),
                 column='TotalPop <5',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <AxesSubplot: >

# %%
# First, create new columns for percentages
tracts_age['PCT_18_to_24'] = tracts_age['TotalPop 18 to 24']/tracts_age['Total Population']*100
tracts_age['PCT_25_to_34'] = tracts_age['TotalPop 25 to 34']/tracts_age['Total Population']*100
tracts_age['PCT_35_to_44'] = tracts_age['TotalPop 35 to 44']/tracts_age['Total Population']*100

# %%
tracts_age.plot(figsize=(12,10),
                 column='PCT_18_to_24',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <AxesSubplot: >

# %%
tracts_age.plot(figsize=(12,10),
                 column='PCT_25_to_34',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <AxesSubplot: >

# %%
tracts_age.plot(figsize=(12,10),
                 column='PCT_35_to_44',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <AxesSubplot: >

# %%
tracts_age[tracts_age.PCT_25_to_34 > 50].plot(figsize=(12,10))
# Out:
# <AxesSubplot: >
